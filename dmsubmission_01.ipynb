# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d=pd.read_csv('data_v2.csv')

# %%
d.head()
# Out:
#    stn_code sampling_date      state   location  \
# 0      77.0    01-02-2004  Karnataka  Bangalore
# 1      77.0    01-06-2004  Karnataka  Bangalore
# 2      77.0    01-08-2004  Karnataka  Bangalore
# 3      77.0    01-09-2004  Karnataka  Bangalore
# 4      77.0    01-12-2004  Karnataka  Bangalore
#
#                                     agency             type   so2   no2  \
# 0  Karnataka State Pollution Control Board  Industrial Area   5.0  58.0
# 1  Karnataka State Pollution Control Board  Industrial Area  12.0  52.0
# 2  Karnataka State Pollution Control Board  Industrial Area  11.0  53.0
# 3  Karnataka State Pollution Control Board  Industrial Area   6.0  15.0
# 4  Karnataka State Pollution Control Board  Industrial Area   7.0  60.0
#
#     rspm    spm location_monitoring_station
# 0  33.50   80.0              Graphite India
# 1  51.67  110.0              Graphite India
# 2  96.00  189.0              Graphite India
# 3  42.33   88.0              Graphite India
# ...

# %%
summary=d.describe()

# %%
summary
# Out:
#           stn_code          so2          no2         rspm          spm
# count  3642.000000  6076.000000  6229.000000  6236.000000  2951.000000
# mean    322.208127    13.014498    33.847219   105.299069   223.936971
# std     184.324213     5.685207    11.730459    75.503894   150.095590
# min      77.000000     2.000000     4.000000    12.670000    50.000000
# 25%      78.000000     8.000000    28.900000    52.000000   134.000000
# 50%     405.000000    14.000000    31.000000    83.000000   183.000000
# 75%     406.000000    15.900000    40.100000   135.000000   254.000000
# max     598.000000    93.000000   186.000000   902.000000  1221.000000

# %%
loc_values={'AMCO Batteries':1,'Anand Rao Circle':2,'Department of Environmental Science, Jnanabharathi Campus, Bangalore University':3,'Graphite India':4,'KHB Indl Area':5,'Peenya Indl. Area':6,'Victoria Hospital':7,'Yeshwanthpura':8}

# %%
d.location_monitoring_station=[loc_values[i] for i in d.location_monitoring_station]

# %%
sns.heatmap(d.isnull(),yticklabels=False,cbar=False)

# %%
d.drop('stn_code',axis=1,inplace=True)

# %%
sns.boxplot(x='location_monitoring_station',y='so2',data=d)

# %%
sns.boxplot(x='location_monitoring_station',y='no2',data=d)

# %%
sns.boxplot(x='location_monitoring_station',y='spm',data=d)

# %%
sns.boxplot(x='location_monitoring_station',y='rspm',data=d)

# %%
sns.distplot(d['so2'].dropna(inplace=False))
# Out:
# C:\Users\LAKSHMI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(d['no2'].dropna(inplace=False))
# Out:
# C:\Users\LAKSHMI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(d['rspm'].dropna(inplace=False))
# Out:
# C:\Users\LAKSHMI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(d['spm'].dropna(inplace=False))
# Out:
# C:\Users\LAKSHMI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(d.dropna(inplace=False))

# %%
sns.countplot(x='location_monitoring_station',data=d.dropna())

# %%
sns.jointplot(x='rspm',y='spm',kind='reg',data=d.dropna())
# Out:
# C:\Users\LAKSHMI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\LAKSHMI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.violinplot(x='location_monitoring_station',y='so2',palette='rainbow',data=d)

# %%
d.drop_duplicates(subset=None,inplace=True)

# %%
d.describe()
# Out:
#                so2          no2         rspm          spm  \
# count  6074.000000  6227.000000  6234.000000  2951.000000
# mean     13.013550    33.849745   105.307185   223.936971
# std       5.685818    11.731221    75.514405   150.095590
# min       2.000000     4.000000    12.670000    50.000000
# 25%       8.000000    28.900000    52.000000   134.000000
# 50%      14.000000    31.000000    83.000000   183.000000
# 75%      15.900000    40.100000   135.000000   254.000000
# max      93.000000   186.000000   902.000000  1221.000000
#
#        location_monitoring_station
# count                  6237.000000
# mean                      4.842713
# std                       2.322351
# min                       1.000000
# 25%                       3.000000
# 50%                       5.000000
# 75%                       7.000000
# max                       8.000000

# %%
sns.boxplot(x='location_monitoring_station',y='no2',data=d)

# %%
q1=d[['no2']].quantile(0.25)
q3=d[['no2']].quantile(0.75)
IQR=q3-q1
print(q1,' ',q3)
# Out:
# no2    28.9
# Name: 0.25, dtype: float64   no2    40.1
# Name: 0.75, dtype: float64

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='location_monitoring_station',y='no2',data=d,palette='winter')

# %%
d1=d.groupby('location_monitoring_station')['no2'].mean()

# %%
d1
# Out:
# location_monitoring_station
# 1    35.566606
# 2    60.798649
# 3    17.779188
# 4    37.693749
# 5    33.895688
# 6    32.442506
# 7    33.812164
# 8    33.489114
# Name: no2, dtype: float64

# %%
count=0

# %%
def impute_no2(cols):
    n = cols[0]
    lmt = cols[1]
    
    if n<float(q1-3*IQR) or n>float(q3+3*IQR):
        return 0
    else:
        return n

# %%
d['no2']=d[['no2','location_monitoring_station']].apply(impute_no2,axis=1)

# %%
sns.boxplot(x='location_monitoring_station',y='no2',data=d,palette='winter')

# %%
d2=d.groupby('location_monitoring_station')['no2'].mean()

# %%
d2
# Out:
# location_monitoring_station
# 1    35.037557
# 2    53.825676
# 3    17.779188
# 4    37.214118
# 5    33.292710
# 6    32.442506
# 7    33.657627
# 8    33.110191
# Name: no2, dtype: float64

# %%
def impute_no2i(cols):
    no2=cols[0]
    lmt=cols[1]
    if pd.isnull(no2):
        if lmt==1:
            return 35
        elif lmt==2:
            return 54
        elif lmt==3:
            return 18
        elif lmt==4:
            return 37
        elif lmt==5 or lmt==6 or lmt==7 or lmt==8:
            return 33
    else:
        return no2

# %%
d['no2']=d[['no2','location_monitoring_station']].apply(impute_no2i,axis=1)

# %%
sns.heatmap(d.isnull(),yticklabels=False,cbar=False)

# %%
d.head()
# Out:
#   sampling_date      state   location  \
# 0    01-02-2004  Karnataka  Bangalore
# 1    01-06-2004  Karnataka  Bangalore
# 2    01-08-2004  Karnataka  Bangalore
# 3    01-09-2004  Karnataka  Bangalore
# 4    01-12-2004  Karnataka  Bangalore
#
#                                     agency             type   so2   no2  \
# 0  Karnataka State Pollution Control Board  Industrial Area   5.0  58.0
# 1  Karnataka State Pollution Control Board  Industrial Area  12.0  52.0
# 2  Karnataka State Pollution Control Board  Industrial Area  11.0  53.0
# 3  Karnataka State Pollution Control Board  Industrial Area   6.0  15.0
# 4  Karnataka State Pollution Control Board  Industrial Area   7.0  60.0
#
#     rspm    spm  location_monitoring_station
# 0  33.50   80.0                            4
# 1  51.67  110.0                            4
# 2  96.00  189.0                            4
# 3  42.33   88.0                            4
# 4  63.33  123.0                            4

# %%
d=d[d.no2!=0]

# %%
sns.heatmap(d.isnull(),yticklabels=False,cbar=False)

# %%
sns.boxplot(x='location_monitoring_station',y='no2',data=d,palette='winter')

# %%
q11=d[['so2']].quantile(0.25)
q31=d[['so2']].quantile(0.75)
IQR1=q31-q11

# %%
d=d[d['so2']>float(q11-3*IQR1)]

# %%
d=d[d['so2']<float(q31+3*IQR1)]

# %%
sns.boxplot(x='location_monitoring_station',y='so2',data=d,palette='winter')

# %%
def impute_so2(cols):
    n = cols[0]
    lmt = cols[1]
    
    if (n<float(q11-1.5*IQR1) or n>float(q31+1.5*IQR1)) and lmt==2:
        return 0
    else:
        return n

# %%
d['so2']=d[['so2','location_monitoring_station']].apply(impute_so2,axis=1)

# %%
sns.boxplot(x='location_monitoring_station',y='so2',data=d,palette='winter')

# %%
d=d[d.so2!=0]

# %%
d3=d.groupby('location_monitoring_station')['so2'].mean()

# %%
d3
# Out:
# location_monitoring_station
# 1    12.900583
# 2     6.605970
# 3     7.611929
# 4    13.509511
# 5    13.461123
# 6    13.836235
# 7    12.323566
# 8    14.162625
# Name: so2, dtype: float64

# %%
d4=d.groupby('location_monitoring_station')['so2'].median()

# %%
d4
# Out:
# location_monitoring_station
# 1    14.0
# 2     6.0
# 3     7.2
# 4    15.0
# 5    14.3
# 6    15.0
# 7    13.0
# 8    15.0
# Name: so2, dtype: float64

# %%
def impute_so2i(cols):
    so2=cols[0]
    lmt=cols[1]
    if pd.isnull(so2):
        if lmt==1:
            return 13
        elif lmt==2:
            return 6
        elif lmt==3:
            return 7
        elif lmt==4:
            return 14
        elif lmt==5:
            return 14
        elif lmt==6:
            return 14
        elif lmt==7:
            return 13
        elif lmt==8:
            return 14
    else:
        return so2

# %%
d['so2']=d[['so2','location_monitoring_station']].apply(impute_so2i,axis=1)

# %%
sns.heatmap(d.isnull(),yticklabels=False,cbar=False)

# %%
d['spm'].fillna(d['spm'].mean(),inplace=True)

# %%
sns.heatmap(d.isnull(),yticklabels=False,cbar=False)

# %%
sns.boxplot(x='location_monitoring_station',y='rspm',data=d,palette='winter')

# %%
q12=d[['rspm']].quantile(0.25)
q32=d[['rspm']].quantile(0.75)
IQR2=q32-q12

# %%
d=d[d['rspm']>float(q12-3*IQR2)]

# %%
d=d[d['rspm']<float(q32+3*IQR2)]

# %%
sns.boxplot(x='location_monitoring_station',y='rspm',data=d,palette='winter')

# %%
from sklearn.preprocessing import StandardScaler

# %%
d.head()
# Out:
#   sampling_date      state   location  \
# 0    01-02-2004  Karnataka  Bangalore
# 1    01-06-2004  Karnataka  Bangalore
# 2    01-08-2004  Karnataka  Bangalore
# 3    01-09-2004  Karnataka  Bangalore
# 4    01-12-2004  Karnataka  Bangalore
#
#                                     agency             type   so2   no2  \
# 0  Karnataka State Pollution Control Board  Industrial Area   5.0  58.0
# 1  Karnataka State Pollution Control Board  Industrial Area  12.0  52.0
# 2  Karnataka State Pollution Control Board  Industrial Area  11.0  53.0
# 3  Karnataka State Pollution Control Board  Industrial Area   6.0  15.0
# 4  Karnataka State Pollution Control Board  Industrial Area   7.0  60.0
#
#     rspm    spm  location_monitoring_station
# 0  33.50   80.0                            4
# 1  51.67  110.0                            4
# 2  96.00  189.0                            4
# 3  42.33   88.0                            4
# 4  63.33  123.0                            4

# %%
def compute_ind(row):
    if row['location_monitoring_station']==1 or row['location_monitoring_station']==2 or row['location_monitoring_station']==3 or row['location_monitoring_station']==7 or row['location_monitoring_station']==8:
        return 0
    else:
        return 1
d['industrial_area']=d.apply(compute_ind,axis=1)

# %%
d.head()
# Out:
#   sampling_date      state   location  \
# 0    01-02-2004  Karnataka  Bangalore
# 1    01-06-2004  Karnataka  Bangalore
# 2    01-08-2004  Karnataka  Bangalore
# 3    01-09-2004  Karnataka  Bangalore
# 4    01-12-2004  Karnataka  Bangalore
#
#                                     agency             type   so2   no2  \
# 0  Karnataka State Pollution Control Board  Industrial Area   5.0  58.0
# 1  Karnataka State Pollution Control Board  Industrial Area  12.0  52.0
# 2  Karnataka State Pollution Control Board  Industrial Area  11.0  53.0
# 3  Karnataka State Pollution Control Board  Industrial Area   6.0  15.0
# 4  Karnataka State Pollution Control Board  Industrial Area   7.0  60.0
#
#     rspm    spm  location_monitoring_station  industrial_area
# 0  33.50   80.0                            4                1
# 1  51.67  110.0                            4                1
# 2  96.00  189.0                            4                1
# ...

# %%
d5=d

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
d6=d

# %%
df_feat1 = pd.DataFrame(d6,columns=d6.columns[5:9])
df_feat1.head()
# Out:
#     so2   no2   rspm    spm
# 0   5.0  58.0  33.50   80.0
# 1  12.0  52.0  51.67  110.0
# 2  11.0  53.0  96.00  189.0
# 3   6.0  15.0  42.33   88.0
# 4   7.0  60.0  63.33  123.0

# %%
X_train, X_test, y_train, y_test = train_test_split(d6.drop(['sampling_date','state','location','agency','type','location_monitoring_station','industrial_area'],axis=1),d6['industrial_area'],
                                                    test_size=0.30,random_state=101)

# %%
error_rate = []

for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=10)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=10')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=36
#
#
# [[720 292]
#  [409 369]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.64      0.71      0.67      1012
#           1       0.56      0.47      0.51       778
#
# avg / total       0.60      0.61      0.60      1790

# %%
from scipy.stats import kurtosis, skew

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d7=d

# %%
trans=d7.drop(['sampling_date','state','location','agency','type','location_monitoring_station','industrial_area'],axis=1)**(1/3)

# %%
d.head()
# Out:
#   sampling_date      state   location  \
# 0    01-02-2004  Karnataka  Bangalore
# 1    01-06-2004  Karnataka  Bangalore
# 2    01-08-2004  Karnataka  Bangalore
# 3    01-09-2004  Karnataka  Bangalore
# 4    01-12-2004  Karnataka  Bangalore
#
#                                     agency             type   so2   no2  \
# 0  Karnataka State Pollution Control Board  Industrial Area   5.0  58.0
# 1  Karnataka State Pollution Control Board  Industrial Area  12.0  52.0
# 2  Karnataka State Pollution Control Board  Industrial Area  11.0  53.0
# 3  Karnataka State Pollution Control Board  Industrial Area   6.0  15.0
# 4  Karnataka State Pollution Control Board  Industrial Area   7.0  60.0
#
#     rspm    spm  location_monitoring_station  industrial_area
# 0  33.50   80.0                            4                1
# 1  51.67  110.0                            4                1
# 2  96.00  189.0                            4                1
# ...

# %%
scaler1 = StandardScaler()

# %%
scaler1.fit(trans)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scf=scaler1.transform(trans)

# %%
df_feat2 = pd.DataFrame(scf,columns=d7.columns[5:9])
df_feat2.head()
# Out:
#         so2       no2      rspm       spm
# 0 -1.666476  1.933183 -1.339427 -2.244615
# 1 -0.009133  1.549979 -0.809791 -1.598341
# 2 -0.196328  1.615823  0.093391 -0.329536
# 3 -1.360022 -1.957039 -1.062999 -2.058332
# 4 -1.085986  2.055016 -0.533427 -1.354899

# %%
scf
# Out:
# array([[-1.66647574,  1.93318294, -1.33942663, -2.24461499],
#        [-0.00913323,  1.54997936, -0.80979143, -1.59834134],
#        [-0.19632787,  1.61582318,  0.09339054, -0.32953594],
#        ...,
#        [-0.00913323, -1.80851081, -0.77628965,  0.15130615],
#        [-0.19632787, -0.91112304, -0.39038644,  0.15130615],
#        [-0.19632787, -1.666049  , -0.60862572,  0.15130615]])

# %%
X_train, X_test, y_train, y_test = train_test_split(scf,d7['industrial_area'],
                                                    test_size=0.30,random_state=101)

# %%
error_rate = []

for i in range(40,80):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(40,80),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=61)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=61')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=61
#
#
# [[726 286]
#  [360 418]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.67      0.72      0.69      1012
#           1       0.59      0.54      0.56       778
#
# avg / total       0.64      0.64      0.64      1790

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.64      0.63      0.63      1012
#           1       0.53      0.53      0.53       778
#
# avg / total       0.59      0.59      0.59      1790

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=150)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.66      0.69      0.68      1012
#           1       0.57      0.54      0.56       778
#
# avg / total       0.62      0.62      0.62      1790

# %%
X_test
# Out:
# array([[-1.36002204, -1.666049  ,  0.37880133,  0.15130615],
#        [ 0.13326318,  0.59671471, -0.54075999, -1.24831264],
#        [-0.39524071, -0.58257947, -0.23034384,  0.15130615],
#        ...,
#        [ 0.75350145,  0.36593557, -1.4264106 , -1.75783856],
#        [ 1.71231385, -0.2618366 ,  0.030897  ,  0.15130615],
#        [ 0.69465923, -0.16265055,  0.31812698,  1.99038469]])

# %%
print(skew(df_feat2['so2']))
# Out:
# -0.7729967870104408

# %%
print(skew(df_feat2['no2']))
# Out:
# -0.37104123716819754

# %%
print(skew(df_feat2['spm']))
# Out:
# 0.9766392676499851

# %%
print(skew(df_feat2['rspm']))
# Out:
# 0.4786741693082354

# %%
d8=d

# %%
trans1=d8.drop(['sampling_date','state','location','agency','type','so2','spm','location_monitoring_station','industrial_area'],axis=1)**(1/3)

# %%
scaler2 = StandardScaler()

# %%
scaler2.fit(trans1)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scf1=scaler2.transform(trans1)

# %%
X_train, X_test, y_train, y_test = train_test_split(scf1,d8['industrial_area'],
                                                    test_size=0.30,random_state=101)

# %%
error_rate = []

for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')
